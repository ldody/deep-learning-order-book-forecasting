# %%
import os, sys
import pandas as pd

cwd = os.getcwd()
display(os.listdir(cwd))
# Out:
# ['.ipynb_checkpoints',
#  'ann_optimization.log',
#  'check err met.ipynb',
#  'check_tif.ipynb',
#  'comparison_opti.ipynb',
#  'CO_resample.ipynb',
#  'create_dataset_comb.ipynb',
#  'eval_results.ipynb',
#  'FR0000045072_FOB_CNN_LSTM_optimization.log',
#  'FR0000051807_20231005_TIF.parquet.gzip',
#  'FR0000073272_FOB_CNN_optimization.log',
#  'FR0000073272_OHLCV_CNN_LSTM_optimization.log',
#  'FR0000073272_OHLCV_CNN_optimization.log',
#  'FR0000073272_OHLCV_LSTM_optimization.log',
#  'FR0000120321_FOB_CNN.parquet.gzip',
#  'FR0000120321_FOB_CNN_LSTM.parquet.gzip',
#  'FR0000120321_OHLCV_FOB_CNN.parquet.gzip',
#  'FR0000120321_True.parquet.gzip',
#  'FR0000120578_OHLCV_CNN.parquet.gzip',
#  'FR0000120578_OHLCV_CNN_LSTM.parquet.gzip',
#  'FR0000120578_OHLCV_LSTM.parquet.gzip',
#  'FR0000120578_True.parquet.gzip',
#  'FR0000120628_20231027_FO.parquet.gzip',
#  'FR0000120644_OHLCV_FOB_CNN_LSTM_optimization.log',
#  'FR0000121485_OHLCV_CNN_LSTM_optimization.log',
# ...

# %%
df = pd.read_parquet('FR0000120578_OHLCV_LSTM.parquet.gzip')
display(df)
# Out:
#      Target_1  Target_2  Target_3  Target_4  Target_5  Target_6  Target_7  \
# 0    0.000046 -0.000797  0.000122  0.000335 -0.000637  0.000040 -0.000178
# 1    0.000093 -0.000820  0.000028  0.000343 -0.000758 -0.000110 -0.000129
# 2    0.000105 -0.000876  0.000048  0.000378 -0.000724 -0.000088 -0.000133
# 3    0.000046 -0.000904  0.000021  0.000289 -0.000607 -0.000115 -0.000143
# 4    0.000060 -0.000859  0.000087  0.000324 -0.000710 -0.000135 -0.000171
# ..        ...       ...       ...       ...       ...       ...       ...
# 392  0.000272 -0.001053  0.000619  0.000378 -0.001144  0.000144  0.000186
# 393 -0.000123 -0.000791  0.000434  0.000412 -0.001023  0.000384  0.000034
# 394 -0.000121 -0.000578  0.000260  0.000464 -0.000817  0.000252 -0.000471
# 395 -0.000205 -0.000876  0.000381  0.000510 -0.000949  0.000244 -0.000408
# 396  0.000082 -0.000900  0.000321  0.000547 -0.000748  0.000075 -0.000166
#
#      Target_8  Target_9  Target_10  ...  Target_91  Target_92  Target_93  \
# ...

# %%
df = pd.read_parquet('FR0000120578_True.parquet.gzip')
display(df)
# Out:
#      Target_1  Target_2  Target_3  Target_4  Target_5  Target_6  Target_7  \
# 0         0.0 -0.001431 -0.000511 -0.001022 -0.002044 -0.002248 -0.001124
# 1         0.0  0.000921  0.000409 -0.000614 -0.000819  0.000307  0.001433
# 2         0.0 -0.000511 -0.001534 -0.001738 -0.000613  0.000511  0.001227
# 3         0.0 -0.001023 -0.001227 -0.000102  0.001023  0.001739  0.002148
# 4         0.0 -0.000205  0.000922  0.002048  0.002765  0.003174  0.002253
# ..        ...       ...       ...       ...       ...       ...       ...
# 392       0.0 -0.002668 -0.000485  0.007156  0.005215  0.003881  0.003153
# 393       0.0  0.002189  0.009850  0.007905  0.006567  0.005837  0.008999
# 394       0.0  0.007645  0.005703  0.004368  0.003640  0.006795  0.007159
# 395       0.0 -0.001927 -0.003251 -0.003974 -0.000843 -0.000482  0.001084
# 396       0.0 -0.001327 -0.002051  0.001086  0.001448  0.003016  0.005671
#
#      Target_8  Target_9  Target_10  ...  Target_91  Target_92  Target_93  \
# ...

# %%
ls = [5,5]
lss = (ls[0],ls[0])
display(lss)
# Out:
# (5, 5)
